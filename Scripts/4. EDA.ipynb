# %% [markdown]
# # 1. Importing Visualization Libraries and Data

# %% [markdown]
# # 2. Correlations and Heatmaps

# %% [markdown]
# # 3. Scatter Plots and Pairplots

# %% [markdown]
# # 4. Categorical Plots

# %% [markdown]
# # 5. Additional Key Questions

# %% [markdown]
# ----

# %% [markdown]
# # 1. Importing Visualization Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# %matplotlib inline

# %%
# Save a palette to a variable:
diverging_colors = sns.diverging_palette(5, 250, n=10)
    
# Use palplot and pass in the variable:
sns.palplot(diverging_colors)

sns.set_palette(diverging_colors)

# %%
#Creating Pathway for data
path =(r'C:\Users\colmu\Desktop\Documents\GitHub Documents\CF_WHR')

# %%
#Importing dataset WHR_GDP_2015to2019
df =pd.read_csv(os.path.join(path,'data','Prepared Data','WHR_GDP_2015to2019.csv'))
df
# Out:
#      year                      Country              region  happiness_rank  \
# 0    2015                  Switzerland      Western Europe               1
# 1    2015                      Iceland      Western Europe               2
# 2    2015                      Denmark      Western Europe               3
# 3    2015                       Norway      Western Europe               4
# 4    2015                       Canada       North America               5
# ..    ...                          ...                 ...             ...
# 777  2019                       Rwanda  Sub-Saharan Africa             152
# 778  2019  United Republic of Tanzania  Sub-Saharan Africa             153
# 779  2019                  Afghanistan       Southern Asia             154
# 780  2019     Central African Republic  Sub-Saharan Africa             155
# 781  2019                  South Sudan  Sub-Saharan Africa             156
#
#      happiness_score  perceptions_of_economy  social_support  \
# ...

# %% [markdown]
# # 2. Correlations and Heatmaps

# %%
df.columns
# Out:
# Index(['year', 'Country', 'region', 'happiness_rank', 'happiness_score',
#        'perceptions_of_economy', 'social_support', 'healthy_life_expectancy',
#        'perceptions_of_freedom', 'perceptions_of_generosity',
#        'perceptions_of_corruption', 'GDP', 'GDP_per_capita',
#        'GDP_per_capita_annual_ growth'],
#       dtype='object')

# %%
#Creating a subset of only values required for EDA analysis

sub = df[['happiness_score','perceptions_of_economy', 'social_support', 'healthy_life_expectancy',
       'perceptions_of_freedom', 'perceptions_of_corruption','perceptions_of_generosity', 'year', 'GDP', 'GDP_per_capita',
       'GDP_per_capita_annual_ growth'
         ]]

# %%
# Correlation Grid with Pandas outlining all correlations
sub.corr()
# Out:
#                                happiness_score  perceptions_of_economy  \
# happiness_score                       1.000000                0.789284
# perceptions_of_economy                0.789284                1.000000
# social_support                        0.648799                0.585966
# healthy_life_expectancy               0.742456                0.784338
# perceptions_of_freedom                0.551258                0.340511
# perceptions_of_corruption             0.400189                0.311364
# perceptions_of_generosity             0.137578               -0.014560
# year                                  0.007065                0.019768
# GDP                                   0.198896                0.208875
# GDP_per_capita                        0.712227                0.712610
# GDP_per_capita_annual_ growth         0.027955               -0.000374
#
#                                social_support  healthy_life_expectancy  \
# ...

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, cmap=sns.diverging_palette(20, 220, n=200), ax = ax) 

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

plt.savefig("seabornheatmapcorr.png")

# %%
#Creating a subset of only values required for EDA analysis

sub2 = df[['happiness_score','perceptions_of_economy','GDP', 'GDP_per_capita',
       'GDP_per_capita_annual_ growth'
         ]]

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub2.corr(), annot = True, cmap=sns.diverging_palette(20, 220, n=200), ax = ax) 

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

plt.title('Correlation Chart')
plt.savefig("seabornheatmapcorr2.png", bbox_inches = 'tight')

# %% [markdown]
# reviewing the heatmap a few variables stand out. Firstly happiness rank has nearly all red squares indicating a negative correlation, which is expected as a lower rank indicated a more positive outcome to the listed variable.
# Looking at indicators of economy -'perceptions_of_economy', 'GDP', 'GDP_per_capita','GDP_per_capita_annual_ growth'
# 'perceptions_of_economy' from the World Happiness report has a strong positive correlation to the happiness score as well as 'GDP_per_capita'. The first represents the participant's perception of economy while the later represent numerical data gathered by the World Bank.
# The other indicators of economy do not show strong correlations to other variables, but spatial analysis may provide more understanding of these variables geographically at later stes.

# %% [markdown]
# # 3. Scatter Plots and Pairplots

# %%
# Create a pair plot for sub_2

g = sns.pairplot(data=sub,
    y_vars=['perceptions_of_economy','GDP', 'GDP_per_capita', 'GDP_per_capita_annual_ growth'],
    x_vars=['happiness_score','perceptions_of_economy', 'social_support', 'healthy_life_expectancy',
       'perceptions_of_freedom', 'perceptions_of_corruption','perceptions_of_generosity','GDP', 'GDP_per_capita',
       'GDP_per_capita_annual_ growth']
        )
g.savefig("Correlationalchart.png", bbox_inches = 'tight')

# %% [markdown]
# The purpose of this analysis is to draw insights between reported happiness indicators and GDP.
# The indicators 'perceptions_of_economy' and 'GDP_per_capita' exhibit positive correlations with both the happiness score and healthy life expectancy. 'GDP_per_capita' involves raw data comparisons among countries with significantly diverse values and as highlighted in earlier steps, the standard deviation is approximately 2-3 times that of the mean which may accont for the variance contributing to a distinct upward trend in most scatterplots in this row.
#
# These variables stand out due to their diverse correlational connections with other happiness indicators so they will be utilized for ongoing exploration.

# %%
# Scatterplot for "GDP_per_capita" & "happiness_score"

g=sns.lmplot(x = "GDP_per_capita", y = "happiness_score", data = df)
g.savefig("scatterplot_gdppercapita_happinessscore")
plt.title('GDP per Capita & Happiness')
# Out:
# Text(0.5, 1.0, 'GDP per Capita & Happiness')

# %% [markdown]
# # 4. Categorical Plots

# %%
# cat plot gdp per capita and happiness_score and region

sns.set(style="ticks")
g = sns.catplot(x="GDP_per_capita", 
                y="happiness_score", 
                hue='region',
                palette=diverging_colors,
                data=df)
plt.title('')
g.savefig("Catplt_gpd_and_happiness.png")

# %% [markdown]
# # 5. Additional Key Questions

# %% [markdown]
# ## Regional exploration

# %%
#plotting order

plot_order = df.groupby('region')['GDP_per_capita'].mean().sort_values(ascending=False).index.values

# bar plot gdp per capita and happiness score

sns.set(style="ticks")
g = sns.barplot(x='region', 
                y="GDP_per_capita", 
                palette=diverging_colors,
                order=plot_order,
                data=df)

g.set_xticklabels(
    g.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.xlabel('')

plt.title('Average GDP per Capita by Region')
plt.savefig("barplt_gdp_region.png", bbox_inches = 'tight')
# Out:
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\2833455130.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.barplot(x='region',
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\2833455130.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(

# %%
#plotting order

plot_order2 = df.groupby('region')['happiness_score'].mean().sort_values(ascending=False).index.values

# bar plot gdp per capita and happiness score

sns.set(style="ticks")
g = sns.barplot(x='region', 
                y="happiness_score", 
                palette=diverging_colors,
                order=plot_order2,
                data=df)

g.set_xticklabels(
    g.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.xlabel('')

plt.title('Average Happiness Score by Region')
plt.savefig("barplt_happiness_region.png", bbox_inches = 'tight')
# Out:
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\2890939722.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.barplot(x='region',
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\2890939722.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(

# %% [raw]
# Comparing regions of the world to GPD and happiness scores groupings can be seen between different parts of the world, their GDP per capita and overall happiness scores.

# %% [markdown]
# ### Geospatial analysis for above barcharts

# %%
#plotting order
g = df.groupby('Country')['GDP_per_capita'].mean().nlargest(15).sort_values(ascending=False).index.values

# bar plot gdp per capita and happiness score

sns.set(style="ticks")
g = sns.barplot(x='Country', 
                y="GDP_per_capita", 
                palette=diverging_colors,
                order= g,
                data=df
               )

g.set_xticklabels(
    g.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.xlabel('')

plt.title('Top 15 Wealthiest Countrys')
plt.savefig("barplt_gdppercapita_country.png", bbox_inches = 'tight')
# Out:
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\3147108425.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.barplot(x='Country',
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\3147108425.py:7: UserWarning:
# The palette list has fewer values (10) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   g = sns.barplot(x='Country',
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\3147108425.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(

# %%
#plotting order
g = df.groupby('Country')['happiness_score'].mean().nlargest(15).sort_values(ascending=False).index.values

# bar plot gdp per capita and happiness score

sns.set(style="ticks")
g = sns.barplot(x='Country', 
                y="happiness_score", 
                palette=diverging_colors,
                order= g,
                data=df
               )

g.set_xticklabels(
    g.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.xlabel('')

plt.title('Top 15 Happiest Countrys')
plt.savefig("barplt_happiness_country.png", bbox_inches = 'tight')
# Out:
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\2878200575.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.barplot(x='Country',
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\2878200575.py:7: UserWarning:
# The palette list has fewer values (10) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   g = sns.barplot(x='Country',
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\2878200575.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(

# %% [markdown]
# ## Time series analysis

# %%
# Time series happiness score
g = sns.lineplot(x='year', 
                y="happiness_score", 
                palette='diverging_colors',
                data=df
               ).set(title='Average Happiness Score 2015 to 2019')
plt.savefig("timeserieshappiness.png")
# Out:
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\3686469756.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   g = sns.lineplot(x='year',

# %%
# bar plot gdp per capita and happiness score
g = sns.lineplot(x='year', 
                y="GDP_per_capita", 
                palette='diverging_colors',
                data=df
               ).set(title='Average World Wide GDP(per capita) 2015 to 2019')
plt.savefig("timeseriesgdpcapita.png")
# Out:
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\1638982700.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   g = sns.lineplot(x='year',

# %%
# Time series gdp per capita
g = sns.lineplot(x='year', 
                y="GDP", 
                palette='diverging_colors',
                data=df
               ).set(title='Average World Wide GDP 2015 to 2019')
# Out:
# C:\Users\colmu\AppData\Local\Temp\ipykernel_5088\411156720.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   g = sns.lineplot(x='year',
