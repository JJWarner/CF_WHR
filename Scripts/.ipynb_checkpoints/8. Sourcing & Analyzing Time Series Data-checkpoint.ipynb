# %% [markdown]
# # 1. Importing libraries and data

# %%
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm 
import os
import warnings 
warnings.filterwarnings("ignore")

plt.style.use('seaborn-v0_8-talk')

# %%
#Creating Pathway for data
path =(r'C:\Users\colmu\Desktop\Documents\GitHub Documents\CF_WHR')

# %%
#Importing dataset OECD Gross domestic product (GDP)
df_OECD =pd.read_csv(os.path.join(path,'data','original Data','GDP by Country',"OECD Gross domestic product (GDP).csv"))
df_OECD
# Out:
#     LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME         Value  \
# 0        AUS       GDP     TOT  USD_CAP         A  2010  42823.927966
# 1        AUS       GDP     TOT  USD_CAP         A  2011  44460.605016
# 2        AUS       GDP     TOT  USD_CAP         A  2012  43911.683304
# 3        AUS       GDP     TOT  USD_CAP         A  2013  47796.022174
# 4        AUS       GDP     TOT  USD_CAP         A  2014  47648.633963
# ..       ...       ...     ...      ...       ...   ...           ...
# 655      SEN       GDP     TOT  USD_CAP         A  2015   3017.267768
# 656      SEN       GDP     TOT  USD_CAP         A  2016   3116.185752
# 657      SEN       GDP     TOT  USD_CAP         A  2017   3238.212275
# 658      SEN       GDP     TOT  USD_CAP         A  2018   3416.702758
# 659      SEN       GDP     TOT  USD_CAP         A  2019   3530.013946
#
#     Flag Codes
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# ...

# %%
#Importing dataset WHR_GDP_2015to2019 
df_WHR =pd.read_csv(os.path.join(path,'data','Prepared Data','WHR_GDP_2015to2019.csv'))
df_WHR
# Out:
#      year                      Country              region  happiness_rank  \
# 0    2015                  Switzerland      Western Europe               1
# 1    2015                      Iceland      Western Europe               2
# 2    2015                      Denmark      Western Europe               3
# 3    2015                       Norway      Western Europe               4
# 4    2015                       Canada       North America               5
# ..    ...                          ...                 ...             ...
# 777  2019                       Rwanda  Sub-Saharan Africa             152
# 778  2019  United Republic of Tanzania  Sub-Saharan Africa             153
# 779  2019                  Afghanistan       Southern Asia             154
# 780  2019     Central African Republic  Sub-Saharan Africa             155
# 781  2019                  South Sudan  Sub-Saharan Africa             156
#
#      happiness_score  perceptions_of_economy  social_support  \
# ...

# %%
df_OECD.shape
# Out:
# (660, 8)

# %%
#aggregating GDP data for time series analysis

df_GDP = df_OECD.groupby(df_OECD['TIME'])['Value'].mean()

# Plot the data using matplotlib.

plt.figure(figsize=(15,5), dpi=100)

plt.plot(df_GDP)
plt.title('GDP')
# Out:
# Text(0.5, 1.0, 'GDP')

# %% [markdown]
# # 2. Data Wrangling

# %%
df_OECD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    660 non-null    object
#  1   INDICATOR   660 non-null    object
#  2   SUBJECT     660 non-null    object
#  3   MEASURE     660 non-null    object
#  4   FREQUENCY   660 non-null    object
#  5   TIME        660 non-null    int64
#  6   Value       660 non-null    float64
#  7   Flag Codes  49 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 41.4+ KB

# %%
df_OECD.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
#renaming columns for clarity

df_OECD = df_OECD.rename(columns={'LOCATION':'country_code', 'TIME':'year', 'Value':'GDP_per_capita'}, inplace=True)

# %%
#dropping columns unrequired for analysis

df_OECD = df_OECD.drop(columns=['INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'Flag Codes'],inplace=True, axis=1)

df_OECD
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 3
#       1 #dropping columns unrequired for analysis
# ----> 3 df_OECD = df_OECD.drop(columns=['INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'Flag Codes'],inplace=True, axis=1)
#       5 df_OECD
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
#aggregating GDP_per_capita data for time series analysis

df_GDP_capita = df.groupby(df['year'])['GDP_per_capita'].mean()

# Plot the data using matplotlib.

plt.figure(figsize=(15,5), dpi=100)

plt.plot(df_GDP_capita)
plt.title('GDP per Capita')
# Out:
# Text(0.5, 1.0, 'GDP per Capita')

# %%
#aggregating GDP data for time series analysis

df_GDP = df.groupby(df['year'])['GDP'].mean()

# Plot the data using matplotlib.

plt.figure(figsize=(15,5), dpi=100)

plt.plot(df_GDP)
plt.title('GDP')
# Out:
# Text(0.5, 1.0, 'GDP')

# %%
#aggregating GDP_per_capita_annual_ growth data for time series analysis

df_GDP_annual = df.groupby(df['year'])['GDP_per_capita_annual_ growth'].mean()

# Plot the data using matplotlib.

plt.figure(figsize=(15,5), dpi=100)

plt.plot(df_GDP_annual)
plt.title('Annual Growth(GDP_per_capita)')
# Out:
# Text(0.5, 1.0, 'Annual Growth(GDP_per_capita)')

# %%
#aggregating perceptions_of_economy data for time series analysis

df_economy = df.groupby(df['year'])['perceptions_of_economy'].mean()

# Plot the data using matplotlib.

plt.figure(figsize=(15,5), dpi=100)

plt.plot(df_economy)
plt.title('WHR Perceptions of Economy')
# Out:
# Text(0.5, 1.0, 'WHR Perceptions of Economy')

# %% [markdown]
# # Decomposition

# %% [markdown]
# ### WHR Happiness Score

# %%
# Decomposing the time series using an additive model

decomposition = sm.tsa.seasonal_decompose(df_happiness, model='additive')

# %%
# Defining a fixed size for all special charts
from pylab import rcParams 

rcParams['figure.figsize'] = 18, 7

# %%
# Plot the separate components

decomposition.plot()
plt.show()

# %% [markdown]
# ### GDP per capita

# %%
# Decomposing the time series using an additive model

decomposition2 = sm.tsa.seasonal_decompose(df_GDP_capita, model='additive')

# %%
# Plot the separate components

decomposition2.plot()
plt.show()
